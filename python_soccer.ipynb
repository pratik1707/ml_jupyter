# %%
import pandas as pd
data_frame = pd.read_csv('FIFA19_official_data.csv')

data_frame.shape
# Out:
# (17943, 64)

# %%
data_frame.describe()
# Out:
#                   ID           Age       Overall     Potential       Special  \
# count   17943.000000  17943.000000  17943.000000  17943.000000  17943.000000
# mean   216447.995263     24.702057     66.331550     71.390793   1599.297665
# std     28988.660489      4.693238      6.879566      6.109331    276.606776
# min        16.000000     15.000000     48.000000     49.000000    718.000000
# 25%    201980.000000     21.000000     62.000000     67.000000   1459.000000
# 50%    223676.000000     24.000000     66.000000     71.000000   1639.000000
# 75%    238359.500000     28.000000     71.000000     75.000000   1790.000000
# max    253155.000000     45.000000     94.000000     95.000000   2349.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              17943.000000  17943.000000  17943.000000   17929.000000
# mean                   1.107897      2.947277      2.368277      20.498355
# std                    0.385554      0.664988      0.765885      16.532651
# min                    1.000000      1.000000      1.000000       1.000000
# 25%                    1.000000      3.000000      2.000000       9.000000
# 50%                    1.000000      3.000000      2.000000      18.000000
# 75%                    1.000000      3.000000      3.000000      28.000000
# max                    5.000000      5.000000      5.000000      99.000000
#
#            Crossing  ...     Composure       Marking  StandingTackle  \
# count  17943.000000  ...  17943.000000  17943.000000    17943.000000
# mean      49.874213  ...     58.791339     47.262386       47.868082
# std       18.430707  ...     11.577572     20.041492       21.638860
# min        5.000000  ...     12.000000      3.000000        2.000000
# 25%       38.000000  ...     52.000000     30.000000       27.000000
# 50%       54.000000  ...     60.000000     53.000000       55.000000
# 75%       64.000000  ...     67.000000     64.000000       66.000000
# max       93.000000  ...     96.000000     94.000000       93.000000
#
#        SlidingTackle      GKDiving    GKHandling     GKKicking  GKPositioning  \
# count   17943.000000  17943.000000  17943.000000  17943.000000   17943.000000
# mean       45.820821     16.776737     16.532018     16.372959      16.539486
# std        21.246583     17.903586     17.107419     16.718275      17.252367
# min         3.000000      1.000000      1.000000      1.000000       1.000000
# 25%        24.000000      8.000000      8.000000      8.000000       8.000000
# 50%        52.000000     11.000000     11.000000     11.000000      11.000000
# 75%        64.000000     14.000000     14.000000     14.000000      14.000000
# max        90.000000     90.000000     92.000000     92.000000      91.000000
#
#          GKReflexes  Best Overall Rating
# count  17943.000000         17943.000000
# mean      16.871816            65.771722
# std       18.212789             6.831813
# min        1.000000            47.000000
# 25%        8.000000            61.000000
# 50%       11.000000            66.000000
# 75%       14.000000            70.000000
# max       93.000000            94.000000
#
# [8 rows x 44 columns]

# %%
data_frame[data_frame['Age'] > 20].sort_values('Age').head()
# Out:
#            ID                Name  Age  \
# 7563   239145        E. Massouema   21
# 1362   242380   Stephen Eustáquio   21
# 1357   220746         A. Živković   21
# 13807  248559           L. Pétrot   21
# 9200   225589             J. Kerr   21
#
#                                                   Photo Nationality  \
# 7563   https://cdn.sofifa.com/players/239/145/19_60.png      France
# 1362   https://cdn.sofifa.com/players/242/380/19_60.png    Portugal
# 1357   https://cdn.sofifa.com/players/220/746/19_60.png      Serbia
# 13807  https://cdn.sofifa.com/players/248/559/19_60.png      France
# 9200   https://cdn.sofifa.com/players/225/589/19_60.png    Scotland
#
#                                           Flag  Overall  Potential  \
# 7563       https://cdn.sofifa.com/flags/fr.png       63         75
# 1362       https://cdn.sofifa.com/flags/pt.png       73         84
# 1357       https://cdn.sofifa.com/flags/rs.png       76         83
# 13807      https://cdn.sofifa.com/flags/fr.png       59         65
# 9200   https://cdn.sofifa.com/flags/gb-sct.png       66         79
#
#                    Club                                         Club Logo  \
# 7563    Valenciennes FC  https://cdn.sofifa.com/teams/110456/light_30.png
# 1362          Cruz Azul    https://cdn.sofifa.com/teams/1878/light_30.png
# 1357         SL Benfica     https://cdn.sofifa.com/teams/234/light_30.png
# 13807  AS Saint-Étienne    https://cdn.sofifa.com/teams/1819/light_30.png
# 9200   St. Johnstone FC  https://cdn.sofifa.com/teams/100804/light_30.png
#
#        ... StandingTackle SlidingTackle  GKDiving GKHandling  GKKicking  \
# 7563   ...           64.0          61.0      15.0       11.0       14.0
# 1362   ...           72.0          64.0      14.0       12.0       15.0
# 1357   ...           64.0          50.0       9.0       11.0        8.0
# 13807  ...           65.0          64.0      15.0        8.0        7.0
# 9200   ...           70.0          66.0      13.0       15.0       14.0
#
#        GKPositioning  GKReflexes Best Position Best Overall Rating  \
# 7563            12.0         6.0            CM                62.0
# 1362            11.0         5.0           CDM                72.0
# 1357             6.0         6.0           CAM                76.0
# 13807           11.0         7.0            CB                60.0
# 9200            11.0        12.0            CB                65.0
#
#       Release Clause
# 7563             NaN
# 1362          €11.4M
# 1357          €24.2M
# 13807          €378K
# 9200           €2.6M
#
# [5 rows x 64 columns]

# %%
counts_Nationality = data_frame["Nationality"].value_counts()
counts_Nationality = counts_Nationality.reset_index()
counts_Nationality.columns= ["Nations","Counts"]
counts_Nationality.head()
# Out:
# Nationality
# England      1662
# Germany      1192
# Spain        1078
# France        942
# Argentina     924
# Name: count, dtype: int64

# %%
def value_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    if 'B' in x:
        return float(x.replace('B', '')) * 1000000000
    return 0.0

df1 = pd.DataFrame(data_frame, columns=['Name', 'Wage', 'Value'])
wage = df1['Wage'].str.replace('[\€,]',"", regex = True).apply(value_to_float)
value = df1['Value'].str.replace('[\€,]',"", regex = True).apply(value_to_float)
df1['Wage'] = wage
df1['Value'] = value
df1['difference'] = df1['Value'] - df1['Wage']
df1.sort_values('difference', ascending=False)
# Out:
#                 Name      Wage        Value   difference
# 22          L. Messi  575000.0  110500000.0  109925000.0
# 88         Neymar Jr  300000.0  108000000.0  107700000.0
# 53           H. Kane  200000.0   96500000.0   96300000.0
# 105        E. Hazard  325000.0   93000000.0   92675000.0
# 4       K. De Bruyne  350000.0   93000000.0   92650000.0
# ...              ...       ...          ...          ...
# 5678        N. Bancu       0.0          0.0          0.0
# 13375       F. Kippe    1000.0          0.0      -1000.0
# 12670      Zhou Ting    2000.0       1000.0      -1000.0
# 2953    H. Sulaimani    5000.0          0.0      -5000.0
# 3761          Hilton   15000.0          0.0     -15000.0
#
# [17943 rows x 4 columns]

# %%
import seaborn as sns
sns.set()
graph = sns.scatterplot(x = 'Wage', y = 'Value', data = df1)
graph
# Out:
# <Axes: xlabel='Wage', ylabel='Value'>

# %%
from bokeh.plotting import figure, show 
#from bokeh.models import HoverTool


TOOLTIPS = HoverTool(tooltips=[
    ("index", "$index"),
    ("(Wage,Value)", "(@Wage, @Value)"),
    ("Name", "@Name")]
)

p = figure(title="Soccer", x_axis_label='Wage', y_axis_label='Value', tools=[TOOLTIPS])
p.circle('Wage', 'Value', size = 10, source = df1)
show(p)
